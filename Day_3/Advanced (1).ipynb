# %%
#Classes
class Dog:
    species = "Canine"  # Class attribute

    def __init__(self, name, age): #__init is a constructor method that initializes when the new object is created
        self.name = name  # Instance attribute   #self refers to current instance of the class
        self.age = age  # Instance attribute

# %%
class Student:
    def __init__(self, name, age):
        self.name = "Prashant"
        self.age = 22

#create an object of the Student class
s1 = Student("Prashant", 22)

print(s1.name)
print(s1.age)
# Out:
# Prashant
# 22

# %%
class Dog:
    species = "Canine"  # Class attribute

    def __init__(self, name, age):
        self.name = name  # Instance attribute
        self.age = age  # Instance attribute

# Creating an object of the Dog class
dog1 = Dog("Buddy", 3)
print(dog1.name) 
print(dog1.species)
# Out:
# Buddy
# Canine

# %%
#"Without a constructor, we need to assign values separately for every object, but with a constructor, all required values are initialized automatically when the object is created."
class Student:

    def __init__(self, name, age, department):
        self.name = name
        self.age = age
        self.department = department

s1 = Student("Prashant", 22, "AIML")

print(s1.name)
# Out:
# Prashant

# %%
#constructor chaining is a technique in object-oriented programming where a constructor calls another constructor in the same class or in the parent class. This allows for code reuse and can help to simplify the initialization of objects.
class Person:

    def __init__(self):
        print("Person Constructor")

class Student(Person):

    def __init__(self):
        Person.__init__(self)
        print("Student Constructor")

s1 = Student()
# Out:
# Person Constructor
# Student Constructor

# %%
#super() is used in a constructor to call the parent class constructor and reuse its initialization code.
class Person:
    def __init__(self, name):
        self.name = name

class Student(Person):
    def __init__(self, name, department):
        super().__init__(name)   # Calls Person's constructor
        self.department = department

s1 = Student("Prashant", "AIML")
print(s1.name)        # Prashant
print(s1.department)  # AIML
# Out:
# Prashant
# AIML

# %%
class Car:

    def __init__(self, car_name, owner, price):
        self.car_name = car_name
        self.owner = owner
        self.price = price

    def display(self):
        print("Car Name :", self.car_name)
        print("Owner    :", self.owner)
        print("Price    :", self.price)

    def __del__(self):
        print("Car object deleted")


car_shop = Car("BMW", "Prashant", 4000)

car_shop.display()

del car_shop
# Out:
# Car Name : BMW
# Owner    : Prashant
# Price    : 4000
# Car object deleted

# %%
#inheritance it allows a class to inherit attributes and methods from another class. The class that inherits is called the child class, and the class being inherited from is called the parent class.
class Teacher:

    def speak(self):
        print("Teacher Speaking")


class Student(Teacher): # Student class inherits from Teacher class

    def study(self):
        print("Student Studying")


s = Student()

s.speak()
s.study()
# Out:
# Teacher Speaking
# Student Studying

# %%
class Animal:
    def __init__(self, name):
        self.name = name

    def info(self):
        print("Animal name:", self.name)

class Dog(Animal):
    def sound(self):
        print(self.name, "barks")

d = Dog("Buddy")
# Inherited method
d.info()     
d.sound()
# Out:
# Animal name: Buddy
# Buddy barks

# %%
# Parent Class: Animal
class Animal:
    def __init__(self, name):
        self.name = name

    def info(self):
        print("Animal name:", self.name)

# Child Class: Dog
class Dog(Animal):
    def __init__(self, name, breed):   
        # Calls constructor based on MRO
        super().__init__(name)  #super() is used to call the constructor of the parent class (Animal) to initialize the name attribute. This ensures that the Dog class inherits the properties of the Animal class.
        self.breed = breed

    def details(self):
        print(self.name, "is a", self.breed)

d = Dog("Buddy", "Golden Retriever")
d.info()      # Parent method
d.details()   # Child method
# Out:
# Animal name: Buddy
# Buddy is a Golden Retriever

# %%
class Person:
    def __init__(self, name):
        self.name = name

class Student(Person):
    def __init__(self, name, department):
        super().__init__(name)  # Super() function Calls Person's constructor
        self.department = department

s1 = Student("Prashant", "AIML")
print(s1.name)        # Prashant
print(s1.department)  # AIML
# Out:
# Prashant
# AIML

# %%
#single inheritance is a type of inheritance where a child class inherits from a single parent class. 

class Parent:
    def func1(self):
        print("This function is in parent class.")

# Derived class
class Child(Parent):
    def func2(self):
        print("This function is in child class.")

# Driver code
obj = Child()
obj.func1()
obj.func2()
# Out:
# This function is in parent class.
# This function is in child class.

# %%
# multiple inheritance 
class Mother:
    mothername = ""

    def mother(self):
        print(self.mothername)

# Base class 2
class Father:
    fathername = ""

    def father(self):
        print(self.fathername)

# Derived class
class Son(Mother, Father):
    def parents(self):
        print("Father :", self.fathername)
        print("Mother :", self.mothername)

s1 = Son()
s1.fathername = "RAM"
s1.mothername = "SITA"
s1.parents()
# Out:
# Father : RAM
# Mother : SITA

# %%
#Multi level ingeritance A <- B <- C
class grandfather:
    def __init__(self, grandfathername):
        self.grandfathername = grandfathername

class father(grandfather):
    def __init__(self, fathername, grandfathername):
        self.fathername = fathername
        grandfather.__init__(self, grandfathername)
    
class son(father):
    def __init__(self, sonname, fathername, grandfathername):
        self.sonname = sonname
        father.__init__(self, fathername, grandfathername)

    def print_name(self):
        print("Son name:", self.sonname)
        print("Father name:", self.fathername)
        print("Grandfather name:", self.grandfathername)

s1 = son("Prince", "RAM", "Shyam")
s1.print_name()
# Out:
# Son name: Prince
# Father name: RAM
# Grandfather name: Shyam

# %%
#Hierarchical inheritance
# Base class
class Parent:
    def func1(self):
        print("This function is in parent class.")

# Derived class 1
class Child1(Parent):
    def func2(self):
        print("This function is in child 1.")

# Derived class 2
class Child2(Parent):
    def func3(self):
        print("This function is in child 2.")

# Driver code
object1 = Child1()
object2 = Child2()

object1.func1()
object1.func2()
object2.func1()
object2.func3()
# Out:
# This function is in parent class.
# This function is in child 1.
# This function is in parent class.
# This function is in child 2.

# %%
#Hybrid inhertiance is a combination of two or more types of inheritance.
class A:

    def displayA(self):
        print("Class A")


class B(A):

    def displayB(self):
        print("Class B")


class C(A):

    def displayC(self):
        print("Class C")


class D(B, C):

    def displayD(self):
        print("Class D")


obj = D()

obj.displayA()
obj.displayB()
obj.displayC()
obj.displayD()
# Out:
# Class A
# Class B
# Class C
# Class D

# %%
#Polymorphism 
class Animal:
    def sound(self):
        return "Some generic sound"

class Dog(Animal):
    def sound(self):
        return "Bark"

class Cat(Animal):
    def sound(self):
        return "Meow"

# Polymorphic behavior
animals = [Dog(), Cat(), Animal()]
for animal in animals:
    print(animal.sound())
# Out:
# Bark
# Meow
# Some generic sound

# %%
# Encapsulation is the practice of restricting access to certain attributes and methods of an object, and only exposing a public interface for interacting with the object. 
class Employee:
    def __init__(self, name, salary):
        self.name = name          # public attribute
        self.__salary = salary    # private attribute

emp = Employee("Fedrick", 50000)
print(emp.name) 

#print(emp.__salary)  # This will raise an AttributeError because __salary is private
# Out:
# Fedrick

# %%
# Encapsulation Public
class Student:

    def __init__(self):
        self.name = "Prashant"


s = Student()

print(s.name)
# Out:
# Prashant

# %%
#Encapsulation Protect
class Employee:

    def __init__(self):
        self._salary = 50000


emp = Employee()

print(emp._salary)
# Out:
# 50000

# %%
class Employee:
    def __init__(self, name, age):
        self.name = name       # public
        self._age = age        # protected

class SubEmployee(Employee):
    def show_age(self):
        print("Age:", self._age)   # Accessible in subclass

emp = SubEmployee("Ross", 30)
print(emp.name)        # Public accessible
emp.show_age()         # Protected accessed through subclass
# Out:
# Ross
# Age: 30

# %%
#Private attributes are not accessible outside the class.
class Bank:

    def __init__(self):
        self.__balance = 5000

b = Bank()

print(b._Bank__balance)
# Out:
# 5000

# %%
#private attributes are not accessible outside the class.
class Employee:
    def __init__(self, name, salary):
        self.name = name          # public
        self.__salary = salary    # private

    def show_salary(self):
        print("Salary:", self.__salary)

emp = Employee("Robert", 60000)
print(emp.name)          # Public accessible
emp.show_salary()        # Accessing private correctly
# print(emp.__salary)    # Error: Not accessible directly
# Out:
# Robert
# Salary: 60000

# %%
#Getter and Setter
class Employee:
    def __init__(self):
        self.__salary = 50000

    def get_salary(self):
        return self.__salary

    def set_salary(self, amount):
        if amount > 0:
            self.__salary = amount

emp = Employee()

print(emp.get_salary())   # 50000
emp.set_salary(60000)
print(emp.get_salary())   # 60000
# Out:
# 50000
# 60000

# %%
#Abstraction >> HIdes the complexity and only shows the essential features of the object. It allows the user to interact with the object without needing to understand its internal workings.
from abc import ABC, abstractmethod #from abc import ABC, abstractmethodShow more lines, abstractmethod = Used to create an abstract method


class Animal(ABC): # Abstract Base class

    @abstractmethod # Abstract method
    def sound(self):
        pass


class Dog(Animal): #Child class that inherits from the abstract base class Animal

    def sound(self):
        print("Dog Barks") # implementation of the abstract method sound() in the Dog class


dog = Dog() #create object of the Dog class which is a subclass of the abstract class Animal

dog.sound()  # calling method
# Out:
# Dog Barks

# %%
# Iterator An iterator is an object that helps you go through items in a collection one by one.
numbers = [10, 20, 30]

it = iter(numbers)   # Create iterator

print(next(it)) # This method returns the next item in the collection.
print(next(it))
print(next(it))
# Out:
# 10
# 20
# 30

# %%
# Define a decorator function that takes another function as an argument
def decorator(func):

    # Define a wrapper function that adds extra behavior
    def wrapper():

        # Code to run before the original function
        print("Program Started")

        # Call the original function passed to the decorator
        func()

        # Code to run after the original function
        print("Program Ended")

    # Return the wrapper function
    return wrapper


# Apply the decorator to the greet() function
@decorator
def greet():

    # Original function code
    print("Hello Prashant")


# Call the decorated function
greet()
# Out:
# Program Started
# Hello Prashant
# Program Ended

# %%
#Genrators
def demo():
    yield 10

print(demo())
# Out:
# <generator object demo at 0x00000209E508BB60>
